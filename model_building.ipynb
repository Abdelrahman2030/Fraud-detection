# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("processed_samples.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  transaction_amount  quantity  customer_age  is_fraudulent  \
# 0           1              292.86         3            22              0
# 1           2               31.46         4            32              0
# 2           3               41.78         5            27              0
# 3           5              119.58         5            26              0
# 4           6              273.27         1            30              0
#
#    account_age_days  transaction_hour  transaction_day  transaction_month  \
# 0               148                 3                3                  1
# 1               146                 6                5                  1
# 2               216                15                4                  3
# 3               215                 3                0                  3
# 4               264                 1                1                  1
#
#    encoded_payment_method  encoded_product_category  encoded_device_used
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71502 entries, 0 to 71501
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   transaction_amount        71502 non-null  float64
#  1   quantity                  71502 non-null  int64
#  2   customer_age              71502 non-null  int64
#  3   is_fraudulent             71502 non-null  int64
#  4   account_age_days          71502 non-null  int64
#  5   transaction_hour          71502 non-null  int64
#  6   transaction_day           71502 non-null  int64
#  7   transaction_month         71502 non-null  int64
#  8   encoded_payment_method    71502 non-null  int64
#  9   encoded_product_category  71502 non-null  int64
#  10  encoded_device_used       71502 non-null  int64
# dtypes: float64(1), int64(10)
# memory usage: 6.0 MB

# %%
df.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %% [markdown]
# # processing the data

# %%
#Test split data
from sklearn.model_selection import train_test_split

train_data, temp_data = train_test_split(df, test_size = 0.4, random_state = 1)
cv_data, test_data = train_test_split(temp_data, test_size = 0.5, random_state = 1)

X_train = np.delete(train_data, 3, axis = 1)
X_cv = np.delete(cv_data, 3, axis = 1)
X_test = np.delete(test_data, 3, axis = 1)

y_train = train_data["is_fraudulent"]
y_cv = cv_data["is_fraudulent"]
y_test = test_data["is_fraudulent"]

# %%
print(f"The size of the training set is {X_train.shape}")
print(f"The size of the cv set is {X_cv.shape}")
print(f"The size of the test set is {X_test.shape}")
# Out:
# The size of the training set is (42901, 10)
# The size of the cv set is (14300, 10)
# The size of the test set is (14301, 10)

# %%
#Scale the data
from sklearn.preprocessing import StandardScaler
standar_scaler = StandardScaler()

X_train = standar_scaler.fit_transform(X_train)
X_cv = standar_scaler.fit_transform(X_cv)
X_test = standar_scaler.fit_transform(X_test)

# %% [markdown]
# # Logistic regression model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Calculate the traning loss
from sklearn.metrics import log_loss

# Predict probabilities for training data
y_train_prob = model.predict(X_train)

# Calculate log-loss
log_loss_value = log_loss(y_train, y_train_prob)
print("Log-Loss on Training Data:", log_loss_value)
# Out:
# Log-Loss on Training Data: 1.6492317569016335

# %%
y_cv_pred = model.predict(X_cv)

cv_loss = log_loss(y_cv, y_cv_pred)
print("Log-Loss on CV Data:", cv_loss)
# Out:
# Log-Loss on CV Data: 1.6534710925357239

# %%
from sklearn.metrics import accuracy_score

# Make predictions on training data
y_train_pred = model.predict(X_train)

# Calculate accuracy
accuracy = accuracy_score(y_train, y_train_pred)

# Calculate accuracy percentage
accuracy_percentage = accuracy * 100
print(f"Percentage of Correct Predictions in the traning: {accuracy_percentage:.2f}%")
# Out:
# Percentage of Correct Predictions in the traning: 95.42%

# %%
# Make predictions on training data
y_cv_pred = model.predict(X_cv)

# Calculate accuracy
accuracy = accuracy_score(y_cv, y_cv_pred)

# Calculate accuracy percentage
accuracy_percentage = accuracy * 100
print(f"Percentage of Correct Predictions in the CV: {accuracy_percentage:.2f}%")
# Out:
# Percentage of Correct Predictions in the CV: 95.41%

# %%
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score

y_test_pred = model.predict(X_test)

test_loss = log_loss(y_test, y_test_pred)
accuracy = accuracy_score(y_test, y_test_pred)

accuracy = accuracy * 100

print(f"The loss in the test set is {test_loss:.2f}")
print(f"The percentage oof correct predictions in the test set is {accuracy:.2f}%")
# Out:
# The loss in the test set is 1.67
# The percentage oof correct predictions in the test set is 95.36%
